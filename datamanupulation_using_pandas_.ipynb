# %% [markdown]
# <a href="https://colab.research.google.com/github/logesh2511/Python_example/blob/main/datamanupulation_using_pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('/content/employees.csv')

data
#type(data)
#data.shape #row and colume
#data.head(6)  # first 6 number
#data.tail(10)  #last 10 element
#data.info()
#data.describe()
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

f= pd.read_csv ('/content/employees.csv')

# type(f)
# f.shape  # rows and columns
# f.head() # display from starting, give no to display no of rowss
# f.tail() # display from end, "
# f.info() # data info (no in each column,names of columns, etc)
# f['Team'] # display a particular column's data
# f[['First Name','Salary','Team']]
# f.iloc[4] # display a row's complete info
#f.iloc[3:7] # display a number of rows excluding that number
#f.iloc[3:7,2:5] # display specific rows and columns
#f.iloc[3:7,['Salary']]

# %%
data_new=data.sort_values('First Name',ascending=True)
data_new
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
data_new.loc[186] #based
# Out:
# First Name                 NaN
# Gender                  Female
# Start Date           2/23/2005
# Last Login Time        9:50 PM
# Salary                  149654
# Bonus %                  1.825
# Senior Management          NaN
# Team                     Sales
# Name: 186, dtype: object

# %%
data_new.iloc[2] #index location is acessed
# Out:
# First Name                     Aaron
# Gender                          Male
# Start Date                 7/22/1990
# Last Login Time              2:53 PM
# Salary                         52119
# Bonus %                       11.343
# Senior Management               True
# Team                 Client Services
# Name: 440, dtype: object

# %%
data_new.isnull().sum() # number of null in the list
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
data_new.dropna(axis=0)
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male   2/17/2012        10:20 AM   61602   11.849
# 327      Aaron   Male   1/29/1994         6:48 PM   58755    5.097
# 440      Aaron   Male   7/22/1990         2:53 PM   52119   11.343
# 137       Adam   Male   5/21/2011         1:45 AM   95327   15.120
# 141       Adam   Male  12/24/1990         8:57 PM  110194   14.727
# ..         ...    ...         ...             ...     ...      ...
# 450     Willie   Male   8/22/2009         1:03 PM   55038   19.691
# 112     Willie   Male  11/27/2003         6:21 AM   64363    4.023
# 175     Willie   Male   2/17/1998         8:20 PM  146651    1.451
# 204     Willie   Male    6/6/2006         9:45 AM   55281    4.935
# 652     Willie   Male   12/5/2009         5:39 AM  141932    1.017
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
data_new.dropna(axis=1) #remove null data but dont use this because the column is deleted
# Out:
#     Start Date Last Login Time  Salary  Bonus %
# 101  2/17/2012        10:20 AM   61602   11.849
# 327  1/29/1994         6:48 PM   58755    5.097
# 440  7/22/1990         2:53 PM   52119   11.343
# 937  1/22/1986         7:39 PM   63126   18.424
# 137  5/21/2011         1:45 AM   95327   15.120
# ..         ...             ...     ...      ...
# 902  5/23/2001         7:52 PM  103877    6.322
# 925  8/23/2000         4:19 PM   95866   19.388
# 946  9/15/1985         1:50 AM  133472   16.941
# 947  7/30/2012         3:07 PM  107351    5.329
# 951  9/14/2010         5:19 AM  143638    9.662
#
# [1000 rows x 4 columns]

# %%
data_new.dropna(axis=0,how="all") #if all the data in row are null then delete
#else Dont delete
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
data_new.dropna(axis=0,how='all')
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
data_new.dropna(axis=0,how='all',subset='Team') #delete if Team is not there  in row
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male   2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male   1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male   7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN   1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male   5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...         ...             ...     ...      ...
# 890        NaN    Male  11/24/2015         3:11 AM  145329    7.100
# 902        NaN    Male   5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female   8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female   9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male   7/30/2012         3:07 PM  107351    5.329
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# ...

# %%
data_new['First Name']=data['First Name'].fillna('unknown')
data_new.isnull().sum()
# Out:
# First Name             0
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
data_gender=data['Gender'].mode()
data_gender
# Out:
# 0    Female
# Name: Gender, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
data_new=data.drop([1,4],axis=0)
data_new
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
filter_Team=data['Team']=='Finance'
data[filter_Team]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 46       Bruce    Male  11/28/2009        10:47 PM  114796    6.796
# ..         ...     ...         ...             ...     ...      ...
# 907  Elizabeth  Female   7/27/1998        11:12 AM  137144   10.081
# 954        Joe    Male   1/19/1980         4:06 PM  119667    1.148
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                 NaN  Finance
# ...

# %%
filter_Salary=(data['Salary'] >= 50000) & (data['Salary'] <= 100000)

data[filter_Salary]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# ..         ...     ...         ...             ...     ...      ...
# 986      Donna  Female  11/26/1982         7:04 AM   82871   17.999
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
data['Team'].value_counts()
# Out:
# Team
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: count, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
filter=data['Start Date']>='2000-02-27'
data[filter]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 993       Tina  Female  5/15/1997         3:53 PM   56450   19.040
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
data['Start Date']=data['Start Date'].astype('datetime64[ns]')
data['Start Date']
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
filter=data['Start Date']>='2000-02-27'
data[filter]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 7          NaN  Female 2015-07-20        10:43 AM   45906   11.598
# 8       Angela  Female 2005-11-22         6:29 AM   95570   18.523
# 9      Frances  Female 2002-08-08         6:51 AM  139852    7.524
# 13        Gary    Male 2008-01-27        11:40 PM  109831    5.831
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male 2013-06-21         5:47 PM   98874    4.479
# 995      Henry     NaN 2014-11-23         6:09 AM  132483   16.655
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 3                True               Finance
# 7                 NaN               Finance
# ...
